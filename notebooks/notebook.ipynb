# %% [markdown]
# # Ej 1

# %%
import sys

sys.path.append("../src/")

import ej_1 
ej_1.estadisticas_texto()
# Out:
# cantidad total de lineas 19
# cant de palabras 137
# el promedio de palabras por linea es 7.2105263157894735
# el total de lineas con mas palabras que el promedio es 8
# ["Special cases aren't special enough to break the rules.", 'In the face of ambiguity, refuse the temptation to guess.', 'There should be one-- and preferably only one --obvious way to do it.', "Although that way may not be obvious at first unless you're Dutch.", 'Although never is often better than *right* now.', "If the implementation is hard to explain, it's a bad idea.", 'If the implementation is easy to explain, it may be a good idea.', "Namespaces are one honking great idea -- let's do more of those!"]
# 8

# %% [markdown]
# # Ej 2

# %%
import sys

sys.path.append("../src/")

import ej_2

ej_2.duracion_playlist()
# Out:
# Duracion total: 46m 53s
# cancion mas corta Imagine
# cancion mas larga Stairway to Heaven

# %% [markdown]
# # Ej 3

# %%
import sys

sys.path.append("../src/")
import ej_3

ej_3.filtro_spoilers()
# Out:
# Ingrese las palabras spoilers separadas por coma:  de, secreto
# La película sigue a un grupo ** astronautas que viajan a Marte en una misión ** rescate El capitán Torres lidera al equipo a través ** tormentas solares y fallos en el sistema ** navegación Al llegar a Marte descubren que la base está abandonada y los suministros destruidos Torres decide sacrificar la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula ** emergencia El final revela que Torres sobrevivió gracias a un pasaje *******

# %% [markdown]
# # Ej 10

# %%
import sys

sys.path.append("../src/")

import ej_10

ej_10.concurso_cocina()
# Out:
# Ronda 1 - Entrada
# Ganador Camila (26)
# Valentina:
#  - Total puntos 24
#  - Rondas ganadas 0
#  - Mejor ronda 24
#  - Promedio 24.0
# Mateo:
#  - Total puntos 22
#  - Rondas ganadas 0
#  - Mejor ronda 22
#  - Promedio 22.0
# Camila:
#  - Total puntos 26
#  - Rondas ganadas 1
#  - Mejor ronda 26
#  - Promedio 26.0
# Santiago:
#  - Total puntos 19
#  - Rondas ganadas 0
#  - Mejor ronda 19
#  - Promedio 19.0
# Lucía:
#  - Total puntos 24
#  - Rondas ganadas 0
#  - Mejor ronda 24
#  - Promedio 24.0
# Ronda 2 - Plato principal
# Ganador Valentina (26)
# Valentina:
#  - Total puntos 50
#  - Rondas ganadas 1
#  - Mejor ronda 26
#  - Promedio 25.0
# Mateo:
#  - Total puntos 46
#  - Rondas ganadas 0
#  - Mejor ronda 24
#  - Promedio 23.0
# Camila:
#  - Total puntos 46
#  - Rondas ganadas 1
#  - Mejor ronda 26
#  - Promedio 23.0
# Santiago:
#  - Total puntos 44
#  - Rondas ganadas 0
#  - Mejor ronda 25
#  - Promedio 22.0
# Lucía:
#  - Total puntos 46
#  - Rondas ganadas 0
# ...

# %% [markdown]
# # Ej 4

# %%
import sys

sys.path.append("../src/")

import ej_4

ej_4.validar_email()
# Out:
# ingrese un email para validar:  @abc
# Email invalido
# ingrese un email para validar:  a
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 7
#       3 sys.path.append("../src/")
#       5 import ej_4
# ----> 7 ej_4.validar_email()
#
# File ~/Programacion/TP2_python/notebooks/../src/ej_4.py:10, in validar_email()
#       6 contiene_arroba = email.count("@") == 1
#       8 tiene_char_antes = len(email.split("@")[0]) > 0
# ---> 10 tiene_punto_despues = email.split("@")[1].count(".") == 1
#      13 no_empieza_con = not email.startswith("@") and not email.startswith(".")
#      15 dos_char_despues = True if "." in email and len(email.split(".")[1]) >= 2 else False
#
# IndexError: list index out of range

# %% [markdown]
# # Ej 5

# %%
import sys

sys.path.append("../src/")

import ej_5

ej_5.calcular_costo_envio()
# Out:
# Ingrese el peso del paquete (kg):  1
# Ingrese la zona del paquete:  reginal
# Zona invalida (local, regonal, nacional)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 import sys
#       3 sys.path.append("../src/")
# ----> 5 import ej_5
#       7 ej_5.calcular_costo_envio()
#
# File ~/Programacion/TP2_python/notebooks/../src/ej_5.py:35
#      30             costo = 8000
#      32     print(f"Costo de envio {costo}")
# ---> 35 calcular_costo_envio()
#
# File ~/Programacion/TP2_python/notebooks/../src/ej_5.py:32, in calcular_costo_envio()
#      29     elif peso >= 5:
#      30         costo = 8000
# ---> 32 print(f"Costo de envio {costo}")
#
# UnboundLocalError: cannot access local variable 'costo' where it is not associated with a value

# %% [markdown]
# # Ej 6

# %%
import sys

sys.path.append("../src/")

import ej_6

ej_6.contar_hashtags()
# Out:
# #Motivación: 2
# #Python: 3
# #Programación: 3
# #SerieAdicta: 2
# #InteligenciaArtificial: 3
# #Tecnología: 2
# Total hashtags unicos 13
# #Motivación: 2
# #Python: 3
# #Programación: 3
# #SerieAdicta: 2
# #InteligenciaArtificial: 3
# #Tecnología: 2
# Total hashtags unicos 13

# %% [markdown]
# # Ej 7

# %%
import sys

sys.path.append("../src/")

import ej_7

ej_7.amigo_invisible()
# Out:
# Ingrese una lista de nombres separados por coma:  a, b, c
# a -> b
# b -> c
# c -> a
# Ingrese una lista de nombres separados por coma:  T, U, V
# T -> V
# U -> T
# V -> U

# %%
# Ej 8

# %%
import sys

sys.path.append("../src/")

import ej_8

ej_8.cifrado_cesar()
# Out:
# Ingrese un mensaje:  a
# Ingrese un desplazamiento:  2
# c
# a
